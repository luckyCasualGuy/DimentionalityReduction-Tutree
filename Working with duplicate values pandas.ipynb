# %%
import pandas as pd
pd.set_option('display.max_rows', 100)
import numpy as np

# %% [markdown]
# # Finding Duplicate values

# %%
df = pd.read_csv('dataset/car.csv')

# %% [markdown]
# Say you have a dataframe like this

# %%
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %% [markdown]
# ## In order to see the count of Say Car_Names repeated you can do something like this
# <a id="Actual_Count"></a>

# %%
NAME = "Car_Name"

n = df.groupby(by=[NAME]).count().iloc[:, 0:1]
n.columns.values[0] = 'Count'

# Making a function out of it for quick use
def duplicate_count(df):
    n = df.groupby(by=[NAME]).count().iloc[:, 0:1]
    n.columns.values[0] = 'Count'
    return n

n
# Out:
#                            Count
# Car_Name
# 800                            1
# Activa 3g                      2
# Activa 4g                      1
# Bajaj  ct 100                  1
# Bajaj Avenger 150              1
# Bajaj Avenger 150 street       1
# Bajaj Avenger 220              3
# Bajaj Avenger 220 dtsi         2
# Bajaj Avenger Street 220       1
# Bajaj Discover 100             1
# Bajaj Discover 125             2
# Bajaj Dominar 400              1
# Bajaj Pulsar  NS 200           1
# Bajaj Pulsar 135 LS            1
# Bajaj Pulsar 150               4
# Bajaj Pulsar 220 F             2
# Bajaj Pulsar NS 200            3
# Bajaj Pulsar RS200             1
# Hero  CBZ Xtreme               1
# Hero  Ignitor Disc             1
# Hero Extreme                   2
# Hero Glamour                   1
# Hero Honda CBZ extreme         1
# Hero Honda Passion Pro         1
# Hero Hunk                      1
# Hero Passion Pro               2
# Hero Passion X pro             1
# ...

# %% [markdown]
# ## If you just wont to know if particular columns of your dataset has duplicate values you can do something like this

# %%
NAME = "Car_Name"

m = df[NAME].duplicated().any()
n = df[NAME].is_unique

f"Value of m: {m} ## Value of n: {n}"
# Out:
# 'Value of m: True ## Value of n: False'

# %% [markdown]
# ## Say Now we want to remove every duplicate car names from Car_Name column but keeping the first occurence

# %%
NAME = "Car_Name"

n = df.drop_duplicates(subset=[NAME])

duplicate_count(n)
# Out:
#                            Count
# Car_Name
# 800                            1
# Activa 3g                      1
# Activa 4g                      1
# Bajaj  ct 100                  1
# Bajaj Avenger 150              1
# Bajaj Avenger 150 street       1
# Bajaj Avenger 220              1
# Bajaj Avenger 220 dtsi         1
# Bajaj Avenger Street 220       1
# Bajaj Discover 100             1
# Bajaj Discover 125             1
# Bajaj Dominar 400              1
# Bajaj Pulsar  NS 200           1
# Bajaj Pulsar 135 LS            1
# Bajaj Pulsar 150               1
# Bajaj Pulsar 220 F             1
# Bajaj Pulsar NS 200            1
# Bajaj Pulsar RS200             1
# Hero  CBZ Xtreme               1
# Hero  Ignitor Disc             1
# Hero Extreme                   1
# Hero Glamour                   1
# Hero Honda CBZ extreme         1
# Hero Honda Passion Pro         1
# Hero Hunk                      1
# Hero Passion Pro               1
# Hero Passion X pro             1
# ...

# %% [markdown]
# ### You can Now see that our new dataframe contains only one occurence of that car and rest  were deleted

# %% [markdown]
# ## Our dataframe has 26 values for a car name city say we only want to delete these 26 values keeping only one occurence of course. <a href="#Actual_Count">Check Here</a>

# %%
NAME = 'Car_Name'
CAR = 'city'

m = df
m['remove'] = np.where(df[NAME] == CAR, True, False)
df.loc[df[NAME] == CAR, :]
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 251     city  2013           5.00           9.90       56701    Petrol
# 253     city  2014           7.20           9.90       48000    Diesel
# 254     city  2013           5.25           9.90       54242    Petrol
# 256     city  2016          10.25          13.60       49562    Petrol
# 257     city  2015           8.50          13.60       40324    Petrol
# 258     city  2015           8.40          13.60       25000    Petrol
# 260     city  2016           9.15          13.60       29223    Petrol
# 267     city  2016           8.35           9.40       19434    Diesel
# 269     city  2015           6.70          10.00       18828    Petrol
# 270     city  2011           4.10          10.00       69341    Petrol
# 271     city  2009           3.00          10.00       69562    Petrol
# 272     city  2015           7.50          10.00       27600    Petrol
# ...
